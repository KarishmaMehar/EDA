# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pymongo
import json
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport
# %matplotlib inline

# %%
data = pd.read_csv("Home_Credit_Default_Risk1.csv")

# %%
data.shape
# Out:
# (10000, 122)

# %%
data_sample = data.head(1000)

# %%
data_sample
# Out:
#      SK_ID_CURR  TARGET  ... AMT_REQ_CREDIT_BUREAU_QRT AMT_REQ_CREDIT_BUREAU_YEAR
# 0        333185       0  ...                       NaN                        NaN
# 1        293761       0  ...                       0.0                        9.0
# 2        192407       0  ...                       0.0                        1.0
# 3        203675       0  ...                       0.0                        2.0
# 4        428596       0  ...                       2.0                        5.0
# ..          ...     ...  ...                       ...                        ...
# 995      199890       0  ...                       0.0                        2.0
# 996      222880       0  ...                       NaN                        NaN
# 997      426020       0  ...                       1.0                        2.0
# 998      285171       0  ...                       1.0                        1.0
# ...

# %%
data2 = pd.read_csv("titanic.csv")

# %%
data2.shape
# Out:
# (891, 12)

# %%
 data2.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
titanic_profile = ProfileReport(data2, title = "Pandas profiling report")

# %%
titanic_profile.to_widgets()
# Out:
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# with visualization also we can detect there is missing value or not

# from above analysis we will getto know age column is having the missing values
data2['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
#heatmap

sns.heatmap(pd.DataFrame(data2['Age']))
# Out:
# <AxesSubplot:>

# %%
# here we are getting error because we are having categorical feature in our dataset, to conver that data set we have diff diff conventions
sns.heatmap(pd.DataFrame(data2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 sns.heatmap(pd.DataFrame(data2))
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:540, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
# ...

# %%
# missing number library(when ever we want to do the interpretation of our data interms of missing values in such cases we can directly import this library and we can plot any plot with the help of this one)
# with out using this library also we can perform the visulization but for that we need to do the column wise analysis

import missingno as msno

# %%
msno.heatmap(data2)
# Out:
# <AxesSubplot:>

# %%
msno.bar(data2)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(data2)
# Out:
# <AxesSubplot:>

# %%
msno.dendrogram(data2)
# Out:
# <AxesSubplot:>
